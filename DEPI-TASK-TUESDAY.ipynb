# %% [markdown]
# # **1**

# %%
lst = [1 , 2 , 3 , 4 , 5]
lst.append(6)
lst[1] = 10
print(lst)
# Out:
# [1, 10, 3, 4, 5, 6]

# %% [markdown]
# # **2**

# %%
my_list = ['apple', 'banana', 'cherry', 'date']
print(my_list[0])
my_list.remove('date')
my_list.insert( 2 , 'grape')
print(my_list)
# Out:
# apple
# ['apple', 'banana', 'grape', 'cherry']

# %% [markdown]
# # **3**

# %%
set = {1, 2, 3, 4}
set.add(5)
print(set)
set.add(3)
set.remove(2)
print(set)
# Out:
# {1, 2, 3, 4, 5}
# {1, 3, 4, 5}

# %% [markdown]
# # **4**

# %%
my_set = {'red', 'green', 'blue'}
print( 'green'  in my_set )
my_set.add("yellow")
my_set.remove("red")
print(my_set
# Out:
# True
# {'green', 'blue', 'yellow'}

# %% [markdown]
# # **5**

# %%
tup = (1, 2, 3, 4, 5)
print(tup[3])
print(tup)
# Out:
# 4
# (1, 2, 3, 4, 5)

# %% [markdown]
# # **6**

# %%
my_tuple = ('apple', 'banana', 'cherry')
print(my_tuple[2])
print('banana' in my_tuple)
print(my_tuple)
# Out:
# cherry
# True
# ('apple', 'banana', 'cherry')

# %% [markdown]
# # **7**

# %%
dic = {'name': 'John', 'age': 25, 'city': 'New York'}
print(dic['name'])
dic['age'] = 26 
dic['job'] = 'Engineer'
print(dic)
# Out:
# John
# {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Engineer'}

# %% [markdown]
# # **8**

# %%
dic = {'brand':'Toyota','model': 'Corolla', 'year': 2019}
print(dic['model'])
del dic['year']
dic['color'] = 'blue'
print(dic)
# Out:
# Corolla
# {'brand': 'Toyota', 'model': 'Corolla', 'color': 'blue'}

# %% [markdown]
# # **EX 1 & EX 2**

# %%
vegs = ('tomato','carrots','cucumber')
fruits = ('banana','strawberry','orange')
fruits_vegetables = vegs + fruits
print(len(fruits_vegetables)) 
food_tuple = fruits_vegetables + ('mushroom', 'coffee')

print(food_tuple)
*fruits_vegetables, mushroom, beverage = food_tuple

print(fruits_vegetables)
print(mushroom)
print(beverage)
food_list = list(food_tuple)

print(food_list)
print(food_list[:3])
print(food_list[-3:])
del food_tuple
# Out:
# 6
# ('tomato', 'carrots', 'cucumber', 'banana', 'strawberry', 'orange', 'mushroom', 'coffee')
# ['tomato', 'carrots', 'cucumber', 'banana', 'strawberry', 'orange']
# mushroom
# coffee
# ['tomato', 'carrots', 'cucumber', 'banana', 'strawberry', 'orange', 'mushroom', 'coffee']
# ['tomato', 'carrots', 'cucumber']
# ['orange', 'mushroom', 'coffee']

# %%
bird = {
    'name': 'Eagle',
    'color': 'Brown',
    'breed': 'Bald Eagle',
    'legs': 2,
    'age': 5
}

student = {
    'firstname': 'Mohamed',
    'lastname': 'Ahmed',
    'gender': 'Male',
    'age': 20,
    'martial_arts': 'Karate',
    'skills': ['Python', 'HTML', 'CSS'],
    'country': 'Egypt',
    'city': 'Ismailia',
    'address': 'Suez Canal Street'
}

print(len(student))
print(student['skills'])
student['skills'].extend(['java','c++'])
keys = list(student.keys())
values = list(student.values())
print(keys)
print(values)
print(student)
student_tuple = tuple(student.items())
print(student_tuple)
del student['martial_arts']
del bird
# Out:
# 9
# ['Python', 'HTML', 'CSS']
# ['firstname', 'lastname', 'gender', 'age', 'martial_arts', 'skills', 'country', 'city', 'address']
# ['Mohamed', 'Ahmed', 'Male', 20, 'Karate', ['Python', 'HTML', 'CSS', 'java', 'c++'], 'Egypt', 'Ismailia', 'Suez Canal Street']
# {'firstname': 'Mohamed', 'lastname': 'Ahmed', 'gender': 'Male', 'age': 20, 'martial_arts': 'Karate', 'skills': ['Python', 'HTML', 'CSS', 'java', 'c++'], 'country': 'Egypt', 'city': 'Ismailia', 'address': 'Suez Canal Street'}
# (('firstname', 'Mohamed'), ('lastname', 'Ahmed'), ('gender', 'Male'), ('age', 20), ('martial_arts', 'Karate'), ('skills', ['Python', 'HTML', 'CSS', 'java', 'c++']), ('country', 'Egypt'), ('city', 'Ismailia'), ('address', 'Suez Canal Street'))
